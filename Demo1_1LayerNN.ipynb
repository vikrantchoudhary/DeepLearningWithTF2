# %%
import tensorflow as tf 
import numpy as np 

print (tf.__version__)
print(np.__version__)
# Out:
# 2.1.0
# 1.17.2

# %%
#basic data
x = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
y = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

#model with layer1
model = tf.keras.Sequential([tf.keras.layers.Dense(units =1 , input_shape=[1])])

model.compile(optimizer='sgd' ,loss = 'mean_squared_error')

model.fit(x,y,epochs = 100)

print(model.predict([10.0])) #expected value is 19. we get better with more data and epochs.
# Out:
# Train on 6 samples
# Epoch 1/100
# 6/6 [==============================] - 0s 21ms/sample - loss: 30.2167
# Epoch 2/100
# 6/6 [==============================] - 0s 164us/sample - loss: 24.0869
# Epoch 3/100
# 6/6 [==============================] - 0s 167us/sample - loss: 19.2578
# Epoch 4/100
# 6/6 [==============================] - 0s 245us/sample - loss: 15.4522
# Epoch 5/100
# 6/6 [==============================] - 0s 222us/sample - loss: 12.4519
# Epoch 6/100
# 6/6 [==============================] - 0s 197us/sample - loss: 10.0854
# Epoch 7/100
# 6/6 [==============================] - 0s 215us/sample - loss: 8.2176
# Epoch 8/100
# 6/6 [==============================] - 0s 206us/sample - loss: 6.7423
# Epoch 9/100
# 6/6 [==============================] - 0s 581us/sample - loss: 5.5759
# Epoch 10/100
# 6/6 [==============================] - 0s 175us/sample - loss: 4.6527
# Epoch 11/100
# 6/6 [==============================] - 0s 214us/sample - loss: 3.9209
# Epoch 12/100
# ...

# %% [markdown]
# Exercise 1 : predict the price of flat: if 50k is the base price and 50k per Bedroom. Input till 4bhk. predict for 7 bhk

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = keras.Sequential([tf.keras.layers.Dense(units =1 , input_shape=[1])])
model.compile(optimizer='sgd' ,loss = 'mean_squared_error')
xs = np.array([1.0,2.0,3.0,4.0],dtype=float)
ys = np.array([100.0,150.0,200.0,250.0],dtype=float)
model.fit(xs,ys,epochs=1000)
print(model.predict([7.0]))
# Out:
# /sample - loss: 1.5400
# Epoch 766/1000
# 4/4 [==============================] - 0s 481us/sample - loss: 1.5308
# Epoch 767/1000
# 4/4 [==============================] - 0s 440us/sample - loss: 1.5216
# Epoch 768/1000
# 4/4 [==============================] - 0s 371us/sample - loss: 1.5125
# Epoch 769/1000
# 4/4 [==============================] - 0s 432us/sample - loss: 1.5035
# Epoch 770/1000
# 4/4 [==============================] - 0s 441us/sample - loss: 1.4945
# Epoch 771/1000
# 4/4 [==============================] - 0s 447us/sample - loss: 1.4855
# Epoch 772/1000
# 4/4 [==============================] - 0s 466us/sample - loss: 1.4767
# Epoch 773/1000
# 4/4 [==============================] - 0s 521us/sample - loss: 1.4678
# Epoch 774/1000
# 4/4 [==============================] - 0s 410us/sample - loss: 1.4591
# Epoch 775/1000
# 4/4 [==============================] - 0s 533us/sample - loss: 1.4503
# Epoch 776/1000
# ...
